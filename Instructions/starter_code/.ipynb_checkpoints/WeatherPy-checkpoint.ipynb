# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)



# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
array_length = len(cities)
array_length
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#call the API and search using the stuff in the cities list

settings = {"units": "metric", "appid": api_key}
city_data = pd.DataFrame()
cnt = 0
i = 0
for i in range(array_length):
    try:
        current_weather = owm.get_current(cities[i], **settings)
        city_data = city_data.append(current_weather, ignore_index=True)
        i += 1
    except: 
        cnt += 1
        i += 1

# %%
print(f"{cnt} cities skipped")
# Out:
# 64 cities skipped

# %%
city_data
# Out:
#          base        clouds    cod                            coord  \
# 0    stations   {'all': 18}  200.0  {'lon': -134.97, 'lat': -23.12}
# 1    stations   {'all': 75}  200.0  {'lon': -169.92, 'lat': -19.06}
# 2    stations   {'all': 75}  200.0   {'lon': 147.06, 'lat': -42.78}
# 3    stations   {'all': 93}  200.0   {'lon': 149.07, 'lat': -23.58}
# 4    stations   {'all': 75}  200.0     {'lon': 57.7, 'lat': -20.41}
# 5    stations   {'all': 94}  200.0    {'lon': 102.47, 'lat': 71.98}
# 6    stations   {'all': 45}  200.0      {'lon': 3.32, 'lat': 14.35}
# 7    stations   {'all': 90}  200.0    {'lon': -97.86, 'lat': 55.74}
# 8    stations   {'all': 75}  200.0     {'lon': 15.63, 'lat': 78.22}
# 9    stations    {'all': 0}  200.0    {'lon': 139.92, 'lat': 53.94}
# 10   stations   {'all': 20}  200.0    {'lon': -27.07, 'lat': 38.73}
# 11   stations   {'all': 41}  200.0    {'lon': -46.05, 'lat': 60.91}
# 12   stations    {'all': 1}  200.0    {'lon': -68.38, 'lat': 49.12}
# 13   stations   {'all': 88}  200.0    {'lon': 152.44, 'lat': -3.66}
# 14   stations  {'all': 100}  200.0    {'lon': -37.64, 'lat': 65.61}
# 15   stations   {'all': 75}  200.0   {'lon': -42.02, 'lat': -22.97}
# 16   stations   {'all': 20}  200.0    {'lon': -25.43, 'lat': 37.72}
# 17   stations    {'all': 0}  200.0    {'lon': 31.88, 'lat': -27.31}
# 18   stations    {'all': 0}  200.0    {'lon': -139.03, 'lat': -9.8}
# 19   stations    {'all': 0}  200.0    {'lon': 18.42, 'lat': -33.93}
# 20   stations    {'all': 1}  200.0    {'lon': -73.48, 'lat': 45.36}
# 21   stations   {'all': 34}  200.0     {'lon': 172.79, 'lat': 3.07}
# 22   stations   {'all': 75}  200.0   {'lon': 147.33, 'lat': -42.88}
# 23   stations   {'all': 60}  200.0     {'lon': 161.3, 'lat': 68.75}
# 24   stations   {'all': 79}  200.0   {'lon': -170.99, 'lat': 65.58}
# 25   stations   {'all': 75}  200.0      {'lon': 38.73, 'lat': 8.96}
# 26   stations  {'all': 100}  200.0      {'lon': -1.69, 'lat': 6.21}
# 27   stations    {'all': 9}  200.0     {'lon': 80.43, 'lat': 47.96}
# 28   stations   {'all': 40}  200.0   {'lon': -70.91, 'lat': -53.16}
# 29   stations    {'all': 0}  200.0     {'lon': 40.92, 'lat': 34.45}
# ..        ...           ...    ...                              ...
# 516  stations   {'all': 90}  200.0   {'lon': -134.39, 'lat': 58.28}
# 517  stations    {'all': 0}  200.0     {'lon': 24.56, 'lat': 48.29}
# 518  stations    {'all': 0}  200.0    {'lon': 46.32, 'lat': -15.72}
# 519  stations  {'all': 100}  200.0       {'lon': 8.57, 'lat': 7.38}
# 520  stations   {'all': 94}  200.0    {'lon': 108.35, 'lat': 57.84}
# 521  stations    {'all': 0}  200.0   {'lon': -43.85, 'lat': -19.77}
# 522  stations  {'all': 100}  200.0    {'lon': 101.72, 'lat': 26.59}
# 523  stations   {'all': 90}  200.0    {'lon': -93.13, 'lat': 35.28}
# 524  stations   {'all': 90}  200.0   {'lon': 146.92, 'lat': -36.08}
# 525  stations    {'all': 0}  200.0   {'lon': 150.85, 'lat': -34.58}
# 526  stations   {'all': 40}  200.0    {'lon': -97.07, 'lat': 15.86}
# 527  stations    {'all': 0}  200.0   {'lon': -114.04, 'lat': 27.97}
# 528  stations    {'all': 0}  200.0    {'lon': 45.17, 'lat': -21.68}
# 529  stations   {'all': 73}  200.0    {'lon': -70.77, 'lat': -8.16}
# 530  stations   {'all': 75}  200.0    {'lon': 120.31, 'lat': 22.62}
# 531  stations   {'all': 90}  200.0     {'lon': -52.96, 'lat': 5.38}
# 532  stations   {'all': 75}  200.0     {'lon': -74.6, 'lat': 45.62}
# 533  stations   {'all': 20}  200.0   {'lon': -102.79, 'lat': 46.88}
# 534  stations    {'all': 0}  200.0    {'lon': 22.74, 'lat': -29.67}
# 535  stations    {'all': 0}  200.0    {'lon': 22.13, 'lat': -30.97}
# 536  stations   {'all': 99}  200.0    {'lon': -12.83, 'lat': 10.08}
# 537  stations   {'all': 66}  200.0    {'lon': 152.7, 'lat': -25.54}
# 538  stations   {'all': 75}  200.0   {'lon': -128.61, 'lat': 54.52}
# 539  stations   {'all': 40}  200.0   {'lon': -45.44, 'lat': -23.68}
# 540  stations    {'all': 0}  200.0    {'lon': 12.15, 'lat': -15.19}
# 541  stations   {'all': 45}  200.0      {'lon': 44.56, 'lat': 50.8}
# 542  stations    {'all': 0}  200.0    {'lon': 22.79, 'lat': -23.67}
# 543  stations    {'all': 0}  200.0     {'lon': 72.58, 'lat': 50.56}
# 544  stations   {'all': 20}  200.0   {'lon': 145.42, 'lat': -16.99}
# 545  stations   {'all': 75}  200.0   {'lon': -122.43, 'lat': 37.46}
#
#                dt         id  \
# 0    1.563235e+09  4030556.0
# 1    1.563235e+09  4036284.0
# 2    1.563236e+09  2155415.0
# 3    1.563235e+09  2175403.0
# 4    1.563236e+09   934322.0
# 5    1.563236e+09  2022572.0
# 6    1.563236e+09  2444995.0
# 7    1.563235e+09  6165406.0
# 8    1.563236e+09  2729907.0
# 9    1.563236e+09  2019935.0
# 10   1.563236e+09  3372760.0
# 11   1.563236e+09  3421719.0
# 12   1.563236e+09  5922281.0
# 13   1.563236e+09  2090021.0
# 14   1.563236e+09  3424607.0
# 15   1.563236e+09  3471451.0
# 16   1.563236e+09  3372472.0
# 17   1.563236e+09   935051.0
# 18   1.563236e+09  4020109.0
# 19   1.563235e+09  3369157.0
# 20   1.563236e+09  6138908.0
# 21   1.563235e+09  2110227.0
# 22   1.563235e+09  2163355.0
# 23   1.563236e+09  2126199.0
# 24   1.563236e+09  4031637.0
# 25   1.563236e+09   344979.0
# 26   1.563236e+09  2296606.0
# 27   1.563236e+09  1525988.0
# 28   1.563235e+09  3874787.0
# 29   1.563236e+09   174448.0
# ..            ...        ...
# 516  1.563236e+09  5554072.0
# 517  1.563236e+09   689037.0
# 518  1.563236e+09  1062663.0
# 519  1.563236e+09  2338660.0
# 520  1.563236e+09  2022083.0
# 521  1.563236e+09  3450144.0
# 522  1.563236e+09  6929460.0
# 523  1.563236e+09  4129397.0
# 524  1.563236e+09  2178174.0
# 525  1.563236e+09  6255012.0
# 526  1.563236e+09  3520994.0
# 527  1.563236e+09  4021858.0
# 528  1.563236e+09  1066831.0
# 529  1.563236e+09  3661980.0
# 530  1.563236e+09  1673820.0
# 531  1.563236e+09  3380290.0
# 532  1.563236e+09  5966843.0
# 533  1.563236e+09  5688789.0
# 534  1.563236e+09   964090.0
# 535  1.563235e+09  1014034.0
# 536  1.563236e+09  2419533.0
# 537  1.563236e+09  2158562.0
# 538  1.563236e+09  6162949.0
# 539  1.563236e+09  6322184.0
# 540  1.563236e+09  3347019.0
# 541  1.563236e+09   500678.0
# 542  1.563236e+09   933692.0
# 543  1.563236e+09  1520327.0
# 544  1.563236e+09  2158767.0
# 545  1.563235e+09  5354943.0
#
#                                                   main                  name  \
# 0    {'temp': 22.91, 'pressure': 1013.06, 'humidity...               Rikitea
# 1    {'temp': 27, 'pressure': 1014, 'humidity': 74,...                 Alofi
# 2    {'temp': 12.15, 'pressure': 1009, 'humidity': ...           New Norfolk
# 3    {'temp': 13.21, 'pressure': 1022.21, 'humidity...                 Bluff
# 4    {'temp': 21.53, 'pressure': 1026, 'humidity': ...             Mahebourg
# 5    {'temp': 16.51, 'pressure': 1012, 'humidity': ...              Khatanga
# 6    {'temp': 33.41, 'pressure': 1008.03, 'humidity...              Filingue
# 7    {'temp': 17, 'pressure': 1005, 'humidity': 88,...              Thompson
# 8    {'temp': 7, 'pressure': 1018, 'humidity': 81, ...          Longyearbyen
# 9    {'temp': 22.11, 'pressure': 1008.97, 'humidity...       Mnogovershinnyy
# 10   {'temp': 19.72, 'pressure': 1027, 'humidity': ...      Praia da Vitoria
# 11   {'temp': 3.61, 'pressure': 1015.04, 'humidity'...                Narsaq
# 12   {'temp': 19.93, 'pressure': 1010, 'humidity': ...    Chute-aux-Outardes
# 13   {'temp': 27.31, 'pressure': 1010.33, 'humidity...             Namatanai
# 14   {'temp': 8, 'pressure': 1013, 'humidity': 87, ...              Tasiilaq
# 15   {'temp': 22, 'pressure': 1016, 'humidity': 88,...       Arraial do Cabo
# 16   {'temp': 19, 'pressure': 1027, 'humidity': 88,...  Vila Franca do Campo
# 17   {'temp': 12, 'pressure': 1023, 'humidity': 87,...              Lavumisa
# 18   {'temp': 26.71, 'pressure': 1009.62, 'humidity...                Atuona
# 19   {'temp': 10.1, 'pressure': 1019, 'humidity': 1...             Cape Town
# 20   {'temp': 24.89, 'pressure': 1016, 'humidity': ...        Saint-Philippe
# 21   {'temp': 28.41, 'pressure': 1008.16, 'humidity...            Butaritari
# 22   {'temp': 12.14, 'pressure': 1009, 'humidity': ...                Hobart
# 23   {'temp': 10.31, 'pressure': 1005.52, 'humidity...              Cherskiy
# 24   {'temp': 20.81, 'pressure': 1004.41, 'humidity...            Lavrentiya
# 25   {'temp': 13, 'pressure': 1026, 'humidity': 93,...                  Lebu
# 26   {'temp': 21.21, 'pressure': 1013.04, 'humidity...                Obuasi
# 27   {'temp': 16.41, 'pressure': 1005.49, 'humidity...                Ayagoz
# 28   {'temp': 4.47, 'pressure': 986, 'humidity': 86...          Punta Arenas
# 29   {'temp': 23.91, 'pressure': 1004.3, 'humidity'...             Abu Kamal
# ..                                                 ...                   ...
# 516  {'temp': 17.69, 'pressure': 1016, 'humidity': ...               Douglas
# 517  {'temp': 12, 'pressure': 1013, 'humidity': 87,...              Vorokhta
# 518  {'temp': 19, 'pressure': 1020, 'humidity': 55,...             Mahajanga
# 519  {'temp': 22.81, 'pressure': 1013.51, 'humidity...                  Yaan
# 520  {'temp': 22.71, 'pressure': 1006.97, 'humidity...           Alekseyevsk
# 521  {'temp': 20.02, 'pressure': 1018, 'humidity': ...           Santa Luzia
# 522  {'temp': 20.51, 'pressure': 1005.78, 'humidity...             Panzhihua
# 523  {'temp': 24.05, 'pressure': 1010, 'humidity': ...          Russellville
# 524  {'temp': 9.57, 'pressure': 1023, 'humidity': 9...                Albury
# 525  {'temp': 14.62, 'pressure': 1017, 'humidity': ...              Flinders
# 526  {'temp': 30, 'pressure': 1010, 'humidity': 74,...      Puerto Escondido
# 527  {'temp': 19.31, 'pressure': 1008.67, 'humidity...        Guerrero Negro
# 528  {'temp': 16.91, 'pressure': 1023.77, 'humidity...              Beroroha
# 529  {'temp': 23.21, 'pressure': 1011.49, 'humidity...              Tarauaca
# 530  {'temp': 29.44, 'pressure': 1006, 'humidity': ...             Kaohsiung
# 531  {'temp': 27.51, 'pressure': 1012.22, 'humidity...             Sinnamary
# 532  {'temp': 24.84, 'pressure': 1015, 'humidity': ...             Grenville
# 533  {'temp': 27.02, 'pressure': 1013, 'humidity': ...             Dickinson
# 534  {'temp': 14.51, 'pressure': 1021.77, 'humidity...               Prieska
# 535  {'temp': 11.41, 'pressure': 1021.03, 'humidity...             Carnarvon
# 536  {'temp': 21.31, 'pressure': 1014.24, 'humidity...                 Galle
# 537  {'temp': 16.71, 'pressure': 1020.88, 'humidity...           Maryborough
# 538  {'temp': 24, 'pressure': 1016, 'humidity': 41,...               Terrace
# 539  {'temp': 18, 'pressure': 1018, 'humidity': 82,...            Porto Novo
# 540  {'temp': 19.41, 'pressure': 1013.87, 'humidity...                Namibe
# 541  {'temp': 15.41, 'pressure': 1010.36, 'humidity...                Rudnya
# 542  {'temp': 9.81, 'pressure': 1023.5, 'humidity':...                  Kang
# 543  {'temp': 17.41, 'pressure': 1008, 'humidity': ...            Osakarovka
# 544  {'temp': 18.46, 'pressure': 1019, 'humidity': ...               Mareeba
# 545  {'temp': 22.07, 'pressure': 1017, 'humidity': ...         Half Moon Bay
#
#               rain                                                sys  \
# 0    {'3h': 2.687}  {'message': 0.0065, 'country': 'PF', 'sunrise'...
# 1              NaN  {'type': 1, 'id': 7306, 'message': 0.0084, 'co...
# 2              NaN  {'type': 1, 'id': 9545, 'message': 0.0066, 'co...
# 3              NaN  {'message': 0.0085, 'country': 'AU', 'sunrise'...
# 4              NaN  {'type': 1, 'id': 2061, 'message': 0.0076, 'co...
# 5              NaN  {'message': 0.0053, 'country': 'RU', 'sunrise'...
# 6              NaN  {'message': 0.0081, 'country': 'NE', 'sunrise'...
# 7              NaN  {'type': 1, 'id': 935, 'message': 0.0066, 'cou...
# 8              NaN  {'type': 1, 'id': 1663, 'message': 0.0072, 'co...
# 9              NaN  {'message': 0.0158, 'country': 'RU', 'sunrise'...
# 10             NaN  {'type': 1, 'id': 6895, 'message': 0.0086, 'co...
# 11             NaN  {'message': 0.0055, 'country': 'GL', 'sunrise'...
# 12             NaN  {'type': 1, 'id': 747, 'message': 0.0073, 'cou...
# 13   {'3h': 0.188}  {'message': 0.0087, 'country': 'PG', 'sunrise'...
# 14             NaN  {'type': 1, 'id': 81, 'message': 0.0098, 'coun...
# 15             NaN  {'type': 1, 'id': 8343, 'message': 0.0063, 'co...
# 16             NaN  {'type': 1, 'id': 6899, 'message': 0.0096, 'co...
# 17             NaN  {'type': 1, 'id': 2051, 'message': 0.008, 'cou...
# 18   {'3h': 0.312}  {'message': 0.0074, 'country': 'PF', 'sunrise'...
# 19             NaN  {'type': 1, 'id': 1899, 'message': 0.0102, 'co...
# 20             NaN  {'type': 1, 'id': 4146, 'message': 0.0098, 'co...
# 21       {'3h': 2}  {'message': 0.0065, 'country': 'KI', 'sunrise'...
# 22             NaN  {'type': 1, 'id': 9545, 'message': 0.007, 'cou...
# 23             NaN  {'message': 0.007, 'country': 'RU', 'sunrise':...
# 24             NaN  {'message': 0.0096, 'country': 'RU', 'sunrise'...
# 25             NaN  {'type': 1, 'id': 2453, 'message': 0.0069, 'co...
# 26             NaN  {'message': 0.013, 'country': 'GH', 'sunrise':...
# 27             NaN  {'message': 0.0135, 'country': 'KZ', 'sunrise'...
# 28             NaN  {'type': 1, 'id': 8487, 'message': 0.0057, 'co...
# 29             NaN  {'message': 0.0071, 'country': 'SY', 'sunrise'...
# ..             ...                                                ...
# 516            NaN  {'type': 1, 'id': 7729, 'message': 0.0079, 'co...
# 517            NaN  {'type': 1, 'id': 8906, 'message': 0.0063, 'co...
# 518            NaN  {'type': 1, 'id': 2143, 'message': 0.0082, 'co...
# 519  {'3h': 0.375}  {'message': 0.0064, 'country': 'NG', 'sunrise'...
# 520            NaN  {'message': 0.0056, 'country': 'RU', 'sunrise'...
# 521            NaN  {'type': 1, 'id': 8381, 'message': 0.0067, 'co...
# 522   {'3h': 0.75}  {'message': 0.0061, 'country': 'CN', 'sunrise'...
# 523   {'1h': 0.57}  {'type': 1, 'id': 5721, 'message': 0.008, 'cou...
# 524            NaN  {'type': 1, 'id': 9540, 'message': 0.0076, 'co...
# 525            NaN  {'type': 1, 'id': 9594, 'message': 0.0101, 'co...
# 526            NaN  {'type': 1, 'id': 7157, 'message': 0.0069, 'co...
# 527            NaN  {'message': 0.0084, 'country': 'MX', 'sunrise'...
# 528            NaN  {'message': 0.0069, 'country': 'MG', 'sunrise'...
# 529  {'3h': 0.188}  {'message': 0.0062, 'country': 'BR', 'sunrise'...
# 530            NaN  {'type': 1, 'id': 7940, 'message': 0.007, 'cou...
# 531            NaN  {'message': 0.0055, 'country': 'GF', 'sunrise'...
# 532            NaN  {'type': 1, 'id': 861, 'message': 0.0093, 'cou...
# 533            NaN  {'type': 1, 'id': 3815, 'message': 0.0072, 'co...
# 534            NaN  {'message': 0.0065, 'country': 'ZA', 'sunrise'...
# 535            NaN  {'message': 0.0066, 'country': 'ZA', 'sunrise'...
# 536            NaN  {'message': 0.0169, 'country': 'GN', 'sunrise'...
# 537            NaN  {'message': 0.0056, 'country': 'AU', 'sunrise'...
# 538            NaN  {'type': 1, 'id': 984, 'message': 0.0071, 'cou...
# 539            NaN  {'type': 1, 'id': 8434, 'message': 0.0064, 'co...
# 540            NaN  {'message': 0.007, 'country': 'AO', 'sunrise':...
# 541            NaN  {'message': 0.0066, 'country': 'RU', 'sunrise'...
# 542            NaN  {'message': 0.0061, 'country': 'BW', 'sunrise'...
# 543            NaN  {'message': 0.0126, 'country': 'KZ', 'sunrise'...
# 544            NaN  {'type': 1, 'id': 9490, 'message': 0.0069, 'co...
# 545            NaN  {'type': 1, 'id': 4322, 'message': 0.0118, 'co...
#
#      timezone                                            weather  \
# 0    -32400.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 1    -39600.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 2     36000.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 3     36000.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 4     14400.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 5     25200.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 6      3600.0  [{'id': 802, 'main': 'Clouds', 'description': ...
# 7    -18000.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 8      7200.0  [{'id': 521, 'main': 'Rain', 'description': 's...
# 9     36000.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 10        0.0  [{'id': 801, 'main': 'Clouds', 'description': ...
# 11    -7200.0  [{'id': 802, 'main': 'Clouds', 'description': ...
# 12   -14400.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 13    36000.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 14    -7200.0  [{'id': 520, 'main': 'Rain', 'description': 'l...
# 15   -10800.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 16        0.0  [{'id': 801, 'main': 'Clouds', 'description': ...
# 17     7200.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 18   -34200.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 19     7200.0  [{'id': 741, 'main': 'Fog', 'description': 'fo...
# 20   -14400.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 21    43200.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 22    36000.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 23    39600.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 24    43200.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 25    10800.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 26        0.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 27    21600.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 28   -10800.0  [{'id': 802, 'main': 'Clouds', 'description': ...
# 29    10800.0  [{'id': 800, 'main': 'Clear', 'description': '...
# ..        ...                                                ...
# 516  -28800.0  [{'id': 501, 'main': 'Rain', 'description': 'm...
# 517   10800.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 518   10800.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 519    3600.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 520   28800.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 521  -10800.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 522   28800.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 523  -18000.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 524   36000.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 525   36000.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 526  -18000.0  [{'id': 802, 'main': 'Clouds', 'description': ...
# 527  -21600.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 528   10800.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 529  -18000.0  [{'id': 500, 'main': 'Rain', 'description': 'l...
# 530   28800.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 531  -10800.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 532  -14400.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 533  -21600.0  [{'id': 801, 'main': 'Clouds', 'description': ...
# 534    7200.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 535    7200.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 536       0.0  [{'id': 804, 'main': 'Clouds', 'description': ...
# 537   36000.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 538  -25200.0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 539  -10800.0  [{'id': 802, 'main': 'Clouds', 'description': ...
# 540    3600.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 541   14400.0  [{'id': 802, 'main': 'Clouds', 'description': ...
# 542    7200.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 543   21600.0  [{'id': 800, 'main': 'Clear', 'description': '...
# 544   36000.0  [{'id': 801, 'main': 'Clouds', 'description': ...
# 545  -25200.0  [{'id': 803, 'main': 'Clouds', 'description': ...
#
#                                         wind  visibility
# 0            {'speed': 6.29, 'deg': 326.821}         NaN
# 1                  {'speed': 5.1, 'deg': 80}     10000.0
# 2                 {'speed': 6.2, 'deg': 240}     10000.0
# 3            {'speed': 3.04, 'deg': 154.269}         NaN
# 4                 {'speed': 5.7, 'deg': 140}     10000.0
# 5            {'speed': 2.68, 'deg': 121.421}         NaN
# 6            {'speed': 7.59, 'deg': 189.786}         NaN
# 7                  {'speed': 2.6, 'deg': 20}     24140.0
# 8                 {'speed': 2.1, 'deg': 270}     10000.0
# 9            {'speed': 2.82, 'deg': 211.844}         NaN
# 10            {'speed': 0.43, 'deg': 324.54}     10000.0
# 11           {'speed': 1.46, 'deg': 195.093}         NaN
# 12                {'speed': 4.1, 'deg': 220}     14484.0
# 13           {'speed': 2.32, 'deg': 216.242}         NaN
# 14                {'speed': 0.5, 'deg': 320}         NaN
# 15                {'speed': 4.1, 'deg': 210}      8000.0
# 16                 {'speed': 3.1, 'deg': 10}     10000.0
# 17                {'speed': 1.5, 'deg': 300}         NaN
# 18           {'speed': 6.64, 'deg': 108.154}         NaN
# 19                  {'speed': 1, 'deg': 340}       200.0
# 20           {'speed': 4.28, 'deg': 247.042}     16093.0
# 21           {'speed': 6.87, 'deg': 213.602}         NaN
# 22                {'speed': 6.2, 'deg': 240}     10000.0
# 23           {'speed': 6.89, 'deg': 271.172}         NaN
# 24           {'speed': 0.91, 'deg': 305.148}         NaN
# 25                {'speed': 2.1, 'deg': 260}     10000.0
# 26           {'speed': 1.41, 'deg': 244.381}         NaN
# 27            {'speed': 8.36, 'deg': 11.456}         NaN
# 28                {'speed': 5.7, 'deg': 340}     10000.0
# 29           {'speed': 5.42, 'deg': 298.181}         NaN
# ..                                       ...         ...
# 516               {'speed': 5.1, 'deg': 110}     16093.0
# 517                 {'speed': 2, 'deg': 230}     10000.0
# 518               {'speed': 2.1, 'deg': 150}     10000.0
# 519           {'speed': 2.58, 'deg': 195.28}         NaN
# 520           {'speed': 4.05, 'deg': 43.691}         NaN
# 521                {'speed': 2.1, 'deg': 50}     10000.0
# 522          {'speed': 0.79, 'deg': 191.753}         NaN
# 523               {'speed': 1.5, 'deg': 200}      4828.0
# 524               {'speed': 3.6, 'deg': 270}     10000.0
# 525               {'speed': 8.2, 'deg': 300}     10000.0
# 526               {'speed': 3.1, 'deg': 230}     16093.0
# 527           {'speed': 7.3, 'deg': 333.579}         NaN
# 528             {'speed': 4.7, 'deg': 84.86}         NaN
# 529          {'speed': 0.87, 'deg': 275.319}         NaN
# 530               {'speed': 3.1, 'deg': 340}     10000.0
# 531          {'speed': 6.38, 'deg': 108.171}         NaN
# 532               {'speed': 2.6, 'deg': 230}     72419.0
# 533               {'speed': 3.6, 'deg': 330}     16093.0
# 534          {'speed': 5.32, 'deg': 359.031}         NaN
# 535            {'speed': 3.99, 'deg': 8.941}         NaN
# 536          {'speed': 1.12, 'deg': 247.388}         NaN
# 537          {'speed': 1.69, 'deg': 220.697}         NaN
# 538  {'speed': 5.7, 'deg': 160, 'gust': 9.3}     32186.0
# 539                 {'speed': 1, 'deg': 110}      8000.0
# 540          {'speed': 3.61, 'deg': 203.017}         NaN
# 541           {'speed': 1.82, 'deg': 94.391}         NaN
# 542           {'speed': 3.62, 'deg': 72.101}         NaN
# 543          {'speed': 4.26, 'deg': 116.914}         NaN
# 544               {'speed': 8.2, 'deg': 120}     10000.0
# 545  {'speed': 5.7, 'deg': 320, 'gust': 8.2}     16093.0
#
# [546 rows x 14 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
output_path = "output_data/cities.csv"

city_data.to_csv(output_path, index=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
